# %% [markdown]
# # Bases de Pandas
#
# Dans cette leçon, nous allons introduire quelques notions fondamentales supplémentaires de [Pandas](https://pandas.pydata.org/pandas-docs/stable/getting_started/overview.html), une puissante bibliothèque Python pour travailler avec des données tabulaires telles que des fichiers CSV.
#
# Nous allons revoir les compétences apprises lors de la dernière leçon et introduire comment :
#
# * Examiner largement les données
# * Travailler avec des données manquantes
# * Renommer, supprimer et ajouter de nouvelles colonnes
# * Effectuer des calculs mathématiques
# * Agréger des sous-ensembles de données

# %%
import pandas as pd

# %%
l = [{'date': '2022-02-12', 'prix': '220', 'devise':'euros'},
     {'date': '2022-02-13', 'prix': '10', 'devise':'euros'},
     {'date': '2022-02-16', 'prix': '30', 'devise':'euros'}]

df = pd.DataFrame(l)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#          date prix devise
# 0  2022-02-12  220  euros
# 1  2022-02-13   10  euros
# 2  2022-02-16   30  euros

# %%
l = [{'date': '2022-02-12', 'prix': '220', 'devise':'euros'},
     {'date': '2022-02-13', 'prix': '10', 'devise':'euros'},
     {'date': '2022-02-16', 'devise':'euros'}]

df = pd.DataFrame(l)

# %%
df
# Out:
#          date prix devise
# 0  2022-02-12  220  euros
# 1  2022-02-13   10  euros
# 2  2022-02-16  NaN  euros

# %%
df.prix
# Out:
# 0    220
# 1     10
# 2    NaN
# Name: prix, dtype: object

# %%
colonne_prix = df['prix']

# %%
colonne_prix[0]
# Out:
# '220'

# %%
df_2 = df[['date', 'prix']]

# %%
df_2
# Out:
#          date prix
# 0  2022-02-12  220
# 1  2022-02-13   10
# 2  2022-02-16  NaN

# %% [markdown]
# ## Lire des CSV

# %%
df2 = pd.read_csv('../data/csv/data_corpus.csv')

# %%
df2
# Out:
#                                             doc_name  date  \
# 0               1861_Segur-comtesse-de_Pauvre-Blaise  1861
# 1                          1845_Sand-George_Teverino  1845
# 2                   1892_Allais-Alphonse_Vive-la-vie  1892
# 3                   1997_Bergounioux-Pierre_La-ligne  1997
# 4                1894_Rachilde_Le-Demon-de-l-Absurde  1894
# ...                                              ...   ...
# 2955  1960_Simenon-Georges_Maigret-et-les-vieillards  1960
# 2956                    1910_Zevaco-Michel_Triboulet  1910
# 2957              1880_Gouraud-Julie_Aller-et-retour  1880
# 2958         1956_Sagan-Françoise_Un-certain-sourire  1956
# 2959          1845_Sue-Eugene_La-coucaratcha_Tome-II  1845
#
#                   auteur                      titre  canon  gender mort_auteur
# 0      comtesse de segur              pauvre blaise  False  female        1874
# 1            george sand                   teverino   True  female        1876
# 2        alphonse allais                vive la vie  False    male        1905
# 3     pierre bergounioux                   la ligne   True    male        20--
# 4               rachilde      le demon de l absurde  False  female        1953
# ...                  ...                        ...    ...     ...         ...
# 2955     georges simenon  maigret et les vieillards   True    male        1989
# 2956       michel zevaco                  triboulet  False    male        1918
# 2957       julie gouraud            aller et retour  False  female        1891
# 2958     françoise sagan         un certain sourire  False  female        2004
# 2959          eugene sue             la coucaratcha   True    male        1857
#
# [2960 rows x 7 columns]

# %%
df2 = pd.read_csv('/home/crazyjeannot/Documents/cours/Python4DH/data/csv/data_corpus.csv')

# %%
df2.index = df2.doc_name

# %%
df2
# Out:
#                                                                                       doc_name  \
# doc_name
# 1861_Segur-comtesse-de_Pauvre-Blaise                      1861_Segur-comtesse-de_Pauvre-Blaise
# 1845_Sand-George_Teverino                                            1845_Sand-George_Teverino
# 1892_Allais-Alphonse_Vive-la-vie                              1892_Allais-Alphonse_Vive-la-vie
# 1997_Bergounioux-Pierre_La-ligne                              1997_Bergounioux-Pierre_La-ligne
# 1894_Rachilde_Le-Demon-de-l-Absurde                        1894_Rachilde_Le-Demon-de-l-Absurde
# ...                                                                                        ...
# 1960_Simenon-Georges_Maigret-et-les-vieillards  1960_Simenon-Georges_Maigret-et-les-vieillards
# 1910_Zevaco-Michel_Triboulet                                      1910_Zevaco-Michel_Triboulet
# 1880_Gouraud-Julie_Aller-et-retour                          1880_Gouraud-Julie_Aller-et-retour
# 1956_Sagan-Françoise_Un-certain-sourire                1956_Sagan-Françoise_Un-certain-sourire
# 1845_Sue-Eugene_La-coucaratcha_Tome-II                  1845_Sue-Eugene_La-coucaratcha_Tome-II
#
#                                                 date              auteur  \
# doc_name
# 1861_Segur-comtesse-de_Pauvre-Blaise            1861   comtesse de segur
# 1845_Sand-George_Teverino                       1845         george sand
# 1892_Allais-Alphonse_Vive-la-vie                1892     alphonse allais
# 1997_Bergounioux-Pierre_La-ligne                1997  pierre bergounioux
# 1894_Rachilde_Le-Demon-de-l-Absurde             1894            rachilde
# ...                                              ...                 ...
# 1960_Simenon-Georges_Maigret-et-les-vieillards  1960     georges simenon
# 1910_Zevaco-Michel_Triboulet                    1910       michel zevaco
# 1880_Gouraud-Julie_Aller-et-retour              1880       julie gouraud
# 1956_Sagan-Françoise_Un-certain-sourire         1956     françoise sagan
# 1845_Sue-Eugene_La-coucaratcha_Tome-II          1845          eugene sue
#
#                                                                     titre  \
# doc_name
# 1861_Segur-comtesse-de_Pauvre-Blaise                        pauvre blaise
# 1845_Sand-George_Teverino                                        teverino
# 1892_Allais-Alphonse_Vive-la-vie                              vive la vie
# 1997_Bergounioux-Pierre_La-ligne                                 la ligne
# 1894_Rachilde_Le-Demon-de-l-Absurde                 le demon de l absurde
# ...                                                                   ...
# 1960_Simenon-Georges_Maigret-et-les-vieillards  maigret et les vieillards
# 1910_Zevaco-Michel_Triboulet                                    triboulet
# 1880_Gouraud-Julie_Aller-et-retour                        aller et retour
# 1956_Sagan-Françoise_Un-certain-sourire                un certain sourire
# 1845_Sue-Eugene_La-coucaratcha_Tome-II                     la coucaratcha
#
#                                                 canon  gender mort_auteur
# doc_name
# 1861_Segur-comtesse-de_Pauvre-Blaise            False  female        1874
# 1845_Sand-George_Teverino                        True  female        1876
# 1892_Allais-Alphonse_Vive-la-vie                False    male        1905
# 1997_Bergounioux-Pierre_La-ligne                 True    male        20--
# 1894_Rachilde_Le-Demon-de-l-Absurde             False  female        1953
# ...                                               ...     ...         ...
# 1960_Simenon-Georges_Maigret-et-les-vieillards   True    male        1989
# 1910_Zevaco-Michel_Triboulet                    False    male        1918
# 1880_Gouraud-Julie_Aller-et-retour              False  female        1891
# 1956_Sagan-Françoise_Un-certain-sourire         False  female        2004
# 1845_Sue-Eugene_La-coucaratcha_Tome-II           True    male        1857
#
# [2960 rows x 7 columns]

# %% [markdown]
# ### Affiche

# %%
df2[:1]
# Out:
#                                doc_name  date             auteur  \
# 0  1861_Segur-comtesse-de_Pauvre-Blaise  1861  comtesse de segur
#
#            titre  canon  gender mort_auteur
# 0  pauvre blaise  False  female        1874

# %%
df2.head(2)
# Out:
#                                doc_name  date             auteur  \
# 0  1861_Segur-comtesse-de_Pauvre-Blaise  1861  comtesse de segur
# 1             1845_Sand-George_Teverino  1845        george sand
#
#            titre  canon  gender mort_auteur
# 0  pauvre blaise  False  female        1874
# 1       teverino   True  female        1876

# %%
df2[:4]
# Out:
#                                doc_name  date              auteur  \
# 0  1861_Segur-comtesse-de_Pauvre-Blaise  1861   comtesse de segur
# 1             1845_Sand-George_Teverino  1845         george sand
# 2      1892_Allais-Alphonse_Vive-la-vie  1892     alphonse allais
# 3      1997_Bergounioux-Pierre_La-ligne  1997  pierre bergounioux
#
#            titre  canon  gender mort_auteur
# 0  pauvre blaise  False  female        1874
# 1       teverino   True  female        1876
# 2    vive la vie  False    male        1905
# 3       la ligne   True    male        20--

# %% [markdown]
# ### Attributs

# %%
df2.shape
# Out:
# (2960, 7)

# %%
list(df2.columns)
# Out:
# ['doc_name', 'date', 'auteur', 'titre', 'canon', 'gender', 'mort_auteur']

# %%
df2.index
# Out:
# Index(['1861_Segur-comtesse-de_Pauvre-Blaise', '1845_Sand-George_Teverino',
#        '1892_Allais-Alphonse_Vive-la-vie', '1997_Bergounioux-Pierre_La-ligne',
#        '1894_Rachilde_Le-Demon-de-l-Absurde',
#        '1963_Beauvoir-Simone-de_La-force-des-choses_1',
#        '1913_Leroux-Gaston_La-Reine-du-Sabbat',
#        '1850_Dumas-Alexandre_Dieu-dispose_II',
#        '1846_Balzac-Honore-de_Le-Message',
#        '2004_Gavalda-Anna_Ensemble-c-est-tout',
#        ...
#        '2004_Angot-Christine_Les-Desaxes', '1879_Greville-Henry_La-Niania',
#        '1881_Tissot-Marcel_La-Veuve-d-Attila',
#        '1953_Simonin-Albert_Touchez-pas-au-grisbi',
#        '1955_Ikor-Roger_Les-eaux-melees',
#        '1960_Simenon-Georges_Maigret-et-les-vieillards',
#        '1910_Zevaco-Michel_Triboulet', '1880_Gouraud-Julie_Aller-et-retour',
#        '1956_Sagan-Françoise_Un-certain-sourire',
#        '1845_Sue-Eugene_La-coucaratcha_Tome-II'],
#       dtype='object', name='doc_name', length=2960)

# %%
df2.head(4)
# Out:
#                                doc_name  date              auteur  \
# 0  1861_Segur-comtesse-de_Pauvre-Blaise  1861   comtesse de segur
# 1             1845_Sand-George_Teverino  1845         george sand
# 2      1892_Allais-Alphonse_Vive-la-vie  1892     alphonse allais
# 3      1997_Bergounioux-Pierre_La-ligne  1997  pierre bergounioux
#
#            titre  canon  gender mort_auteur
# 0  pauvre blaise  False  female        1874
# 1       teverino   True  female        1876
# 2    vive la vie  False    male        1905
# 3       la ligne   True    male        20--

# %%
df2.iloc[3,0]
# Out:
# '1997_Bergounioux-Pierre_La-ligne'

# %%
df3 = df2[df2['date'] == 1977]

# %%
df3
# Out:
#                                         doc_name  date                auteur  \
# 291   1977_San-Antonio_Remets-ton-slip-gondolier  1977           antonio san
# 926       1977_Pagnol-Marcel_Le-temps-des-amours  1977         marcel pagnol
# 1136  1977_Ernaux-Annie_Ce-qu-ils-disent-ou-rien  1977          annie ernaux
# 1410  1977_Yourcenar-Marguerite_Archives-du-Nord  1977  marguerite yourcenar
# 1715      1977_Modiano-Patrick_Livret-de-famille  1977       patrick modiano
# 1845               1977_Gary-Romain_Charge-d-ame  1977           romain gary
# 2391                    1977_A.D.G_Le-grand-mome  1977                 a.d.g
# 2745                 1977_A-D-G._Juste-un-rigolo  1977                d g. a
#
#                           titre  canon  gender mort_auteur
# 291   remets ton slip gondolier  False    male        2000
# 926         le temps des amours  False    male        1974
# 1136   ce qu ils disent ou rien   True  female        20--
# 1410           archives du nord   True  female        1987
# 1715          livret de famille   True    male        20--
# 1845               charge d ame   True    male        1980
# 2391              le grand mome  False    male        2004
# 2745            juste un rigolo  False    male        2004

# %%
df2[(df2['date'] < 1907) & (df2['auteur'] == "delly")]
# Out:
#                     doc_name  date auteur        titre  canon  gender  \
# 1487  1905_Delly_L'etincelle  1905  delly  l'etincelle  False  female
#
#      mort_auteur
# 1487        1947

# %% [markdown]
# ## Methodes de Pandas
#
# | Méthode Pandas | Explication                                       |
# |---------------|---------------------------------------------------|
# | `.sum()`      | Somme des valeurs                                 |
# | `.mean()`     | Moyenne des valeurs                               |
# | `.median()`   | Médiane des valeurs                               |
# | `.min()`      | Minimum                                           |
# | `.max()`      | Maximum                                           |
# | `.mode()`     | Mode                                              |
# | `.std()`      | Écart-type non biaisé                             |
# | `.count()`    | Nombre total de valeurs non vides                  |
# | `.value_counts()` | Fréquence des valeurs uniques                    |
# | `.groupby()`  | Division des données en groupes basés sur des critères spécifiques. Permet d'appliquer des opérations sur ces groupes. |
# | `.sort_values()` | Trie les valeurs dans un DataFrame ou une Series. |
# | `.describe()` | Génère des statistiques descriptives pour les données, comme la moyenne, l'écart-type et les quartiles. |

# %%
df3 = df2.sort_values(['date'])#, ascending=False

# %%
df3
# Out:
#                                                doc_name  date  \
# 653   1811_Chateaubriand-François-Rene-de_Oeuvres-co...  1811
# 2173             1812_Kock-Paul-de_L-enfant-de-ma-femme  1812
# 1179                      1815_Gay-Sophie_Anatole_Vol-2  1815
# 623                       1815_Gay-Sophie_Anatole_Vol-1  1815
# 94    1816_Barthelemy-Hadot-Marie-Adelaide_La-Vierge...  1816
# ...                                                 ...   ...
# 1270         2018_Quignard-Pascal_L-enfant-d-Ingolstadt  2018
# 2850              2019_Murail-Marie-Aude_Sauveur-Fils_5  2019
# 322   2019_Dabos-Christelle_La-Passe-miroir_4-La-Tem...  2019
# 2159             2020_Springora-Vanessa_Le-consentement  2020
# 2725           2020_Melois-Clementine_Dehors-la-tempete  2020
#
#                                auteur  \
# 653    françois rene de chateaubriand
# 2173                     paul de kock
# 1179                       sophie gay
# 623                        sophie gay
# 94    hadot marie adelaide barthelemy
# ...                               ...
# 1270                  pascal quignard
# 2850                marie aude murail
# 322                  christelle dabos
# 2159                vanessa springora
# 2725                clementine melois
#
#                                                   titre  canon  gender  \
# 653                                   oeuvres completes   True    male
# 2173                               l enfant de ma femme  False    male
# 1179                                            anatole  False  female
# 623                                             anatole  False  female
# 94    la vierge de l indostan ou les portugais au ma...  False  female
# ...                                                 ...    ...     ...
# 1270                              l enfant d ingolstadt   True    male
# 2850                                       sauveur fils  False  female
# 322                                     la passe miroir  False  female
# 2159                                    le consentement  False  female
# 2725                                  dehors la tempete  False  female
#
#      mort_auteur
# 653         1848
# 2173        1871
# 1179        1852
# 623         1852
# 94          1821
# ...          ...
# 1270        XXXX
# 2850     unknown
# 322         XXXX
# 2159        XXXX
# 2725        XXXX
#
# [2960 rows x 7 columns]

# %%
df3 = df2.groupby('date')['doc_name'].count()

# %%
df2.date.mean()

# %%
df2.canon.describe()

# %%
df2.canon.value_counts()

# %%
df2['auteur'].value_counts()#[:10]

# %%
import numpy as np

# %%
tmp_np = np.linspace(0, 10, num=len(df2))

# %%
df2['numpy'] = tmp_np

# %% [markdown]
# ## + graphiques à partir de Pandas (semaine prochaine)

# %%
data.groupby('date')['doc_name'].count().plot(title='Nombre de Romans par an')

# %%
df2[:1]
# Out:
#                                doc_name  date             auteur  \
# 0  1861_Segur-comtesse-de_Pauvre-Blaise  1861  comtesse de segur
#
#            titre  canon  gender mort_auteur
# 0  pauvre blaise  False  female        1874

# %% [markdown]
# ### Exercices !
#
# x/ Afficher le dataframe du roman 'pauvre blaise'
#
# x/ Afficher le dataframe de l'auteur 'romain gary'
#
# x/ Afficher le dataframe des auteurs morts avant 1865
#
# x/ Afficher le dataframe des autrices femmes qui sont canoniques
#
# x/ Afficher le dataframe des autrices femmes qui sont canoniques avant 1878
